# %%
import sys

# %%
sys.argv
# Out:
# [&apos;-c&apos;, &apos;-f&apos;, &apos;/home/pi/.ipython/profile_default/security/kernel-db66c039-0495-44e1-9043-01511626f6ca.json&apos;, &apos;--pylab=inline&apos;, &quot;--KernelApp.parent_appname=&apos;ipython-notebook&apos;&quot;, &apos;--parent=1&apos;]

# %%
run -i hw1
# Out:
# ******************************from initial conditions
# Optimization terminated successfully.         Current function value: 7.977309         Iterations: 45         Function evaluations: 87ProbExact = 0.09241
# JND = 0.01505 PSE = 0.05839 chi square = 8parametric bootstrap
# ...
# .Correlation1  = [[ 1.         -0.03255608] [-0.03255608  1.        ]]Correlation2  = -0.04341stdChi  = 2.542covar  = [[  0.00001378  -0.0008633 ] [ -0.0008633   51.01201571]]meanChi  = 4.467SqrtOfVar  = [ 0.00371273  7.14226965]meanParams  = [  0.05626312  69.49406167]SEchiPredicted  = 2.828pvalue_chisq  = 0.3464SEParams  = [ 0.00321532  6.18538695]Nonparametric bootstrap
# ...
# ...

# %%
run -i hw1 2
# Out:
# ******************************[&apos;hw1.py&apos;, &apos;2&apos;]from initial conditions
# Optimization terminated successfully.         Current function value: 1.172368         Iterations: 31         Function evaluations: 58ProbExact = 0.5564
# JND = 1.022 PSE = 0.01023 chi square = 1.2parametric bootstrap
# ...
# .Correlation1  = [[ 1.          0.32326966] [ 0.32326966  1.        ]]Correlation2  = 0.431stdChi  = 2.102covar  = [[  0.60892768   2.23085651] [  2.23085651  78.20736812]]meanChi  = 3.007SqrtOfVar  = [ 0.78033818  8.84349298]meanParams  = [-0.3792207   5.13236126]SEchiPredicted  = 2.449pvalue_chisq  = 0.2223SEParams  = [ 0.67579269  7.65868958]Nonparametric bootstrap
# ..
# ..
# ...

# %%
run -i hw1 2 3 contour
# Out:
# ******************************[&apos;hw1.py&apos;, &apos;2&apos;, &apos;3&apos;, &apos;contour&apos;]from initial conditions
# Optimization terminated successfully.         Current function value: 1.172368         Iterations: 31         Function evaluations: 58ProbExact = 0.5564 JND = 1.022 PSE = 0.01023 chi square = 1.2parametric bootstrap
# ..
# .Correlation1  = [[ 1.         -0.50982532] [-0.50982532  1.        ]]Correlation2  = -0.7647stdChi  = 3.249covar  = [[ 1854.86175467  -831.42465879] [ -831.42465879  1433.80947631]]meanChi  = 3.207SqrtOfVar  = [ 43.068106    37.86567676]meanParams  = [ 25.84896833  22.70155968]SEchiPredicted  = 2.449pvalue_chisq  = 0.2012SEParams  = [ 35.1649613   30.91719561]Nonparametric bootstrap
# ...
# ...
